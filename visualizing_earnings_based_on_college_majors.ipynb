# %% [markdown]
# # Visualizing Earnings Based on College Majors
#
# In this project we will be exploring and visualizing a dataset about college graduates from the US who graduated between 2010 and 2012.
#
# The original data is found [here](https://www.census.gov/programs-surveys/acs/) But we will be using a cleaned version by FiveThirtyEight which is [this one](https://github.com/fivethirtyeight/data/tree/master/college-majors).
#
# This is mainly a Data Visualization exercise.
# # Data Collection (Retrieved Dataset)
# we will start by importing the necessary libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Jupyter magic
# %matplotlib inline

# %%
# Read dataset into a DataFrame
recent_grads = pd.read_csv('recent-grads.csv')

# first row
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
# familiarize ourselves with the data by exploring first few and last few items.

recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
# generate summary stats for all numeric columns
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# # Data Cleaning
#
# - In this portion we will drop rows with missing values

# %%
# Unadusted count
recent_grads_index = recent_grads.index
raw_data_count = len(recent_grads_index)
print(raw_data_count)
# Out:
# 173

# %%
# Adjustment and count
recent_grads = recent_grads.dropna()
# count
recent_grads_index = recent_grads.index
cleaned_data_count = len(recent_grads_index)
print(cleaned_data_count)
# Out:
# 172

# %% [markdown]
# It seems that only one row contains missing values.

# %% [markdown]
# # Exploratory Data Analysis and Data Visualization
#
# # Pandas, Scatter Plots
# - We will build scatter plots to start exploring data and start to pick up insights regarding our preliminary questions.

# %%
# Scatter plot for Sample_size and Median
# series and dataframe plot method
# alternative code recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', figsize=(5,10))
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax.set_title('Median vs. Sample_size')

# %%
# Scatter plot for Sample_size and Unemployment_rate
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax.set_title('Unemployment_rate vs. Sample_size')

# %%
# Scatter plot for Full_time and Median
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax.set_title('Median vs. Full_time')

# %%
# Scatter plot for ShareWomen and Unemployment_rate
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax.set_title('Unemployment_rate vs. ShareWomen')

# %%
# Scatter plot for Men and Median
ax = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax.set_title('Median vs. Men')

# %%
# Scatter plot for Women and Median
ax = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax.set_title('Median vs. Women')

# %% [markdown]
# # Pandas, Histograms
#
# In this portion we will explore the distribution of data points using binning to see the frequency of occurence in each column data.

# %%
# One cell run 4 Histograms.
#alternative code recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

columns = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen', 'Unemployment_rate', 'Men', 'Women']

fig = plt.figure(figsize = (5, 12))

for i in range(0,4):
    ax = fig.add_subplot(4,1,1+i)
    ax = recent_grads[columns[i]].plot(kind = 'hist', rot = 35)

# %%
# One cell run 4 Histograms.

columns = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen', 'Unemployment_rate', 'Men', 'Women']

fig = plt.figure(figsize = (5,12))

for i in range(4,8):
    ax = fig.add_subplot(4,1,i-3) # 4 - 3 = 1, 5 - 3 = 2 . . . 
    ax = recent_grads[columns[i]].plot(kind = 'hist', rot = 35)

# %% [markdown]
# # Pandas, Scatter Matrix Plot
#
# We will first import the scatter_matrix function from the pandas.plotting module.
#
# We will be building a matrix which is a combination of scatter plots and histograms.

# %%
# import
from pandas.plotting import scatter_matrix
# plot sample size and median in a 2 by 2 matrix.
scatter_matrix(recent_grads[['Sample_size','Median']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a1da673c8>,
# ...
#       dtype=object)

# %%
# plot sample size, median and unemployment rate in a 3 by 3 matrix
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a1dc918d0>,
# ...
#       dtype=object)

# %% [markdown]
# # Pandas, Bar Plots
#
# We will use Bar plots to check for women percentages in majors first.

# %%
recent_grads[:10].plot.bar(x ='Major', y ='ShareWomen', legend = False)
recent_grads[163:].plot.bar(x ='Major', y ='ShareWomen', legend = False)

# %% [markdown]
# Let's visualize sharewomen and recent grads.

# %%
recent_grads[:10].plot.bar(x ='Major', y ='Unemployment_rate', legend = False)
recent_grads[163:].plot.bar(x ='Major', y ='Unemployment_rate', legend = False)

# %%
recent_grads[:10].plot.bar(x ='Major', y ='Median', legend = False)
recent_grads[163:].plot.bar(x ='Major', y ='Median', legend = False)

# %% [markdown]
# `Do students in more popular majors make more money?`
# - In the first 10 majors based on popularity we can observe that the median salary range is playing in the 80 to 90 thousand USD range while the bottom ten is around 20-25 thousand USD. Therefore, There is a high possibility that students in more popular majors earn more.
#
# `Do students that majored in subjects that were majority female make more money`
# - Based on analysis this is not the case. There is no strong trend on higher median salaries and majors with majority women population. Based on observation the bottom 10 majors are populated by women. In the top 10 only astronomy and astrophysics is women populated (>50%) which earn higher median salaries.
#
# `Is there any link between the number of full-time employees and median salary?`
# - Being a fulltime employee does not always guarantee higher median salaries since a majority of the datapoints lie on 0 upto a few thousands which means that part-time employees or different arrangements can match or may even get higher salaries than fulltime employees.
